# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
# grabbing the gasoline data and putting it in a DataFrame
# renaming the columns as the data is brought in to be its true name
df = pd.read_csv("./data/gas_prices.csv", names=['Date',
                                                 'All Grades All Formulations Retail Gasoline Prices',
                                                 'All Grades Conventional Retail Gasoline Prices',
                                                 'All Grades Reformulated Retail Gasoline Prices',
                                                 'Regular All Formulations Retail Gasoline Prices',
                                                 'Regular Conventional Retail Gasoline Prices',
                                                 'Regular Reformulated Retail Gasoline Prices',
                                                 'Midgrade All Formulations Retail Gasoline Prices',
                                                 'Midgrade Conventional Retail Gasoline Prices',
                                                 'Midgrade Reformulated Retail Gasoline Prices',
                                                 'Premium All Formulations Retail Gasoline Prices',
                                                 'Premium Conventional Retail Gasoline Prices',
                                                 'Premium Reformulated Retail Gasoline Prices',
                                                 'No 2 Diesel Retail Prices'
                                                ], header=0)

# %%
# print df to make sure all data is there
print(df)
# Out:
#             Date  All Grades All Formulations Retail Gasoline Prices  \
# 0     01/02/1995                                              1.127
# 1     01/09/1995                                              1.134
# 2     01/16/1995                                              1.126
# 3     01/23/1995                                              1.132
# 4     01/30/1995                                              1.131
# ...          ...                                                ...
# 1356  12/28/2020                                              2.330
# 1357  01/04/2021                                              2.336
# 1358  01/11/2021                                              2.403
# 1359  01/18/2021                                              2.464
# 1360  01/25/2021                                              2.478
#
#       All Grades Conventional Retail Gasoline Prices  \
# 0                                              1.104
# ...

# %%
plt.plot(df['Date'], df['All Grades All Formulations Retail Gasoline Prices'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 plt.plot(df['Date'], df['All Grades All Formulations Retail Gasoline Prices'])
#       2 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py:222, in caching_module_getattr.<locals>.__getattr__(name)
#     220 if name in props:
#     221     return props[name].__get__(instance)
# --> 222 raise AttributeError(
#     223     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'
